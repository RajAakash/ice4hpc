# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

# Load data from CSV
file_path = 'ApplicationData/TestDFFT/TestDfft(Quartz-Corona).csv'
data = pd.read_csv(file_path)

# Assuming the first two columns contain text data
text_data_col1 = data.iloc[:, 0]
text_data_col2 = data.iloc[:, 1]
rest_of_data = data.iloc[:, 2:]

# Vectorize first text column using TF-IDF
vectorizer_col1 = TfidfVectorizer(max_features=1000)  # Adjust the number of features as needed
tfidf_features_col1 = vectorizer_col1.fit_transform(text_data_col1).toarray()

# Vectorize second text column using TF-IDF
vectorizer_col2 = TfidfVectorizer(max_features=500)  # Adjust the number of features as needed
tfidf_features_col2 = vectorizer_col2.fit_transform(text_data_col2).toarray()

# Define the autoencoder for the first text column (embedding to 10 dimensions)
input_dim_col1 = tfidf_features_col1.shape[1]
encoding_dim_col1 = 10

input_layer_col1 = Input(shape=(input_dim_col1,))
encoded_col1 = Dense(128, activation='relu')(input_layer_col1)
encoded_col1 = Dense(encoding_dim_col1, activation='relu')(encoded_col1)
decoded_col1 = Dense(128, activation='relu')(encoded_col1)
decoded_col1 = Dense(input_dim_col1, activation='sigmoid')(decoded_col1)
autoencoder_col1 = Model(input_layer_col1, decoded_col1)

# Encoder for extracting embeddings for the first column
encoder_col1 = Model(input_layer_col1, encoded_col1)

# Compile and train the autoencoder for the first column
autoencoder_col1.compile(optimizer='adam', loss='mse')
autoencoder_col1.fit(tfidf_features_col1, tfidf_features_col1, epochs=50, batch_size=256, validation_split=0.2)

# Define the autoencoder for the second text column (embedding to 5 dimensions)
input_dim_col2 = tfidf_features_col2.shape[1]
encoding_dim_col2 = 5

input_layer_col2 = Input(shape=(input_dim_col2,))
encoded_col2 = Dense(128, activation='relu')(input_layer_col2)
encoded_col2 = Dense(encoding_dim_col2, activation='relu')(encoded_col2)
decoded_col2 = Dense(128, activation='relu')(encoded_col2)
decoded_col2 = Dense(input_dim_col2, activation='sigmoid')(decoded_col2)
autoencoder_col2 = Model(input_layer_col2, decoded_col2)

# Encoder for extracting embeddings for the second column
encoder_col2 = Model(input_layer_col2, encoded_col2)

# Compile and train the autoencoder for the second column
autoencoder_col2.compile(optimizer='adam', loss='mse')
autoencoder_col2.fit(tfidf_features_col2, tfidf_features_col2, epochs=50, batch_size=256, validation_split=0.2)

# Extract embeddings
embeddings_col1 = encoder_col1.predict(tfidf_features_col1)
embeddings_col2 = encoder_col2.predict(tfidf_features_col2)

# Convert embeddings to DataFrames
embeddings_df_col1 = pd.DataFrame(embeddings_col1, columns=[f'emb_col1_{i+1}' for i in range(encoding_dim_col1)])
embeddings_df_col2 = pd.DataFrame(embeddings_col2, columns=[f'emb_col2_{i+1}' for i in range(encoding_dim_col2)])

# Combine embeddings with the rest of the data
final_data = pd.concat([embeddings_df_col1, embeddings_df_col2, rest_of_data.reset_index(drop=True)], axis=1)

# Save the combined data to CSV
final_data.to_csv('EncoderData/TestDFFT/TestDfft(Quartz-Corona)_encoding.csv', index=False)

print("Data with embeddings saved to 'machine_embeddings_from_autoencoder.csv")
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.2537 - val_loss: 0.2496
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2496 - val_loss: 0.2461
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2461 - val_loss: 0.2424
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2424 - val_loss: 0.2387
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2387 - val_loss: 0.2352
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2352 - val_loss: 0.2316
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2316 - val_loss: 0.2280
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2280 - val_loss: 0.2241
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2241 - val_loss: 0.2204
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2204 - val_loss: 0.2166
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2166 - val_loss: 0.2128
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2128 - val_loss: 0.2090
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2090 - val_loss: 0.2051
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2051 - val_loss: 0.2010
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2010 - val_loss: 0.1969
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1969 - val_loss: 0.1926
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1926 - val_loss: 0.1883
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1883 - val_loss: 0.1838
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1838 - val_loss: 0.1792
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1792 - val_loss: 0.1746
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1746 - val_loss: 0.1698
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1698 - val_loss: 0.1650
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1650 - val_loss: 0.1601
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1601 - val_loss: 0.1551
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1551 - val_loss: 0.1501
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1501 - val_loss: 0.1450
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1450 - val_loss: 0.1399
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1399 - val_loss: 0.1348
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1348 - val_loss: 0.1296
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1296 - val_loss: 0.1244
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1244 - val_loss: 0.1192
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1192 - val_loss: 0.1141
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1141 - val_loss: 0.1089
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1089 - val_loss: 0.1038
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1038 - val_loss: 0.0988
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0988 - val_loss: 0.0939
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0939 - val_loss: 0.0890
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0890 - val_loss: 0.0842
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0842 - val_loss: 0.0796
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0796 - val_loss: 0.0750
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0750 - val_loss: 0.0706
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0706 - val_loss: 0.0664
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0664 - val_loss: 0.0623
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0623 - val_loss: 0.0583
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0583 - val_loss: 0.0546
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0546 - val_loss: 0.0509
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0509 - val_loss: 0.0475
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0475 - val_loss: 0.0442
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0442 - val_loss: 0.0411
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0411 - val_loss: 0.0382
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.2533 - val_loss: 0.2488
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2488 - val_loss: 0.2446
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2446 - val_loss: 0.2407
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2407 - val_loss: 0.2370
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2370 - val_loss: 0.2333
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2333 - val_loss: 0.2296
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2296 - val_loss: 0.2260
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2260 - val_loss: 0.2223
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2223 - val_loss: 0.2185
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2185 - val_loss: 0.2146
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2146 - val_loss: 0.2106
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2106 - val_loss: 0.2065
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2065 - val_loss: 0.2022
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2022 - val_loss: 0.1978
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1978 - val_loss: 0.1933
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1933 - val_loss: 0.1886
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1886 - val_loss: 0.1838
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1838 - val_loss: 0.1789
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1789 - val_loss: 0.1739
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1739 - val_loss: 0.1688
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1688 - val_loss: 0.1635
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1635 - val_loss: 0.1582
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1582 - val_loss: 0.1528
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1528 - val_loss: 0.1474
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1474 - val_loss: 0.1419
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1419 - val_loss: 0.1363
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1363 - val_loss: 0.1308
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1308 - val_loss: 0.1251
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1251 - val_loss: 0.1195
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1195 - val_loss: 0.1139
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1139 - val_loss: 0.1084
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1084 - val_loss: 0.1028
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1028 - val_loss: 0.0974
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0974 - val_loss: 0.0920
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0920 - val_loss: 0.0867
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0867 - val_loss: 0.0816
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0816 - val_loss: 0.0766
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0766 - val_loss: 0.0717
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0717 - val_loss: 0.0670
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0670 - val_loss: 0.0624
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0624 - val_loss: 0.0581
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0581 - val_loss: 0.0539
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0539 - val_loss: 0.0499
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0499 - val_loss: 0.0461
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0461 - val_loss: 0.0426
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0426 - val_loss: 0.0392
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0392 - val_loss: 0.0360
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0360 - val_loss: 0.0331
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0331 - val_loss: 0.0303
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0303 - val_loss: 0.0278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Data with embeddings saved to 'machine_embeddings_from_autoencoder.csv
