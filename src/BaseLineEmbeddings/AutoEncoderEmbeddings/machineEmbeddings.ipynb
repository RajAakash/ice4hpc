# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

# Load data from CSV
file_path = 'Machine.csv'
data = pd.read_csv(file_path)

# Assuming the first column contains text
text_data = data.iloc[:, 0]
rest_of_data = data.iloc[:, 1:]

# Vectorize text data using TF-IDF
vectorizer = TfidfVectorizer(max_features=1000)  # Adjust the number of features
tfidf_features = vectorizer.fit_transform(text_data).toarray()

# Building the autoencoder˜
input_dim = tfidf_features.shape[1]
encoding_dim = 10  # Embeddings size

input_layer = Input(shape=(input_dim,))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(encoding_dim, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)
autoencoder = Model(input_layer, decoded)

# Encoder for extracting embeddings
encoder = Model(input_layer, encoded)

# Compile and train
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(tfidf_features, tfidf_features, epochs=50, batch_size=256, validation_split=0.2)

# Extract embeddings
embeddings = encoder.predict(tfidf_features)

# Combine embeddings with the rest of the data
embeddings_df = pd.DataFrame(embeddings, columns=[f'emb_{i+1}' for i in range(encoding_dim)])
final_data = pd.concat([embeddings_df, rest_of_data.reset_index(drop=True)], axis=1)

# Save the combined data to CSV
final_data.to_csv('machine_embeddings_from_autoencoder.csv', index=False)

print("Data with embeddings saved to 'combined_data.csv'")
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.2407 - val_loss: 0.2383
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2390 - val_loss: 0.2366
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2373 - val_loss: 0.2350
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2355 - val_loss: 0.2332
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2336 - val_loss: 0.2313
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2316 - val_loss: 0.2293
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2295 - val_loss: 0.2272
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2272 - val_loss: 0.2250
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2248 - val_loss: 0.2226
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2222 - val_loss: 0.2200
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2195 - val_loss: 0.2173
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2166 - val_loss: 0.2144
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2134 - val_loss: 0.2112
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2101 - val_loss: 0.2079
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2065 - val_loss: 0.2043
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2027 - val_loss: 0.2006
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1987 - val_loss: 0.1966
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1944 - val_loss: 0.1924
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1900 - val_loss: 0.1880
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1852 - val_loss: 0.1833
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1803 - val_loss: 0.1784
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1751 - val_loss: 0.1733
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1697 - val_loss: 0.1680
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1641 - val_loss: 0.1625
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1583 - val_loss: 0.1568
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1523 - val_loss: 0.1509
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1462 - val_loss: 0.1450
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1400 - val_loss: 0.1390
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1337 - val_loss: 0.1329
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1274 - val_loss: 0.1268
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1211 - val_loss: 0.1208
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1149 - val_loss: 0.1148
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1088 - val_loss: 0.1090
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1029 - val_loss: 0.1034
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0972 - val_loss: 0.0981
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0918 - val_loss: 0.0930
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0868 - val_loss: 0.0883
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0822 - val_loss: 0.0840
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0780 - val_loss: 0.0800
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0743 - val_loss: 0.0765
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0709 - val_loss: 0.0734
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0681 - val_loss: 0.0707
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0656 - val_loss: 0.0683
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0636 - val_loss: 0.0663
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0619 - val_loss: 0.0647
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0605 - val_loss: 0.0633
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0594 - val_loss: 0.0622
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0585 - val_loss: 0.0613
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0579 - val_loss: 0.0605
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0574 - val_loss: 0.0600
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Data with embeddings saved to 'combined_data.csv'
